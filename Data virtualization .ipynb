# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv('listings.csv')

# %%
data
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
# sn.barplot(x= 'room_type' , y = 'price', data = listings)
# plt.show()



sn.barplot(x= 'room_type', y= 'price', data =data)
plt.show()

# %%
sn.countplot(x='room_type' , data = data)
plt.show()

# sn.countplot(x = 'room_type' , data = listings)
# plt.show()

# %%
sn.barplot(x= 'neighbourhood_group' , y = 'price', data = data, ci = False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.head(9)
# Out:
#      id                                              name  host_id  \
# 0  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 1  3831                   Cozy Entire Floor of Brownstone     4869
# 2  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 3  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 4  5121                                   BlissArtsSpace!     7356
# 5  5178                  Large Furnished Room Near B'way      8967
# 6  5203                Cozy Clean Guest Room - Family Apt     7490
# 7  5222                                     Best Hideaway     7516
# 8  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0    Elisabeth           Manhattan              Harlem  40.80902  -73.94190
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# ...

# %%
data.tail(6)
# Out:
#              id                                       name    host_id  \
# 48371  38563645                            Prewar elegance  280444188
# 48372  38564068                          Top Floor Delight  207204450
# 48373  38564524                      Central Park Elegance    1567562
# 48374  38566777                       Quiet room available  159902221
# 48375  38567542       Spacious room in Brooklyn brownstone   68905617
# 48376  38568081  Petrose home by JFK, Beach &St John Hosp.  293596932
#
#       host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 48371       Ann           Manhattan  Upper East Side  40.77290  -73.95835
# 48372       Ade            Brooklyn    Cypress Hills  40.67618  -73.90764
# 48373    Maggie           Manhattan  Upper East Side  40.77326  -73.96650
# 48374     Nancy            Brooklyn         Bushwick  40.69907  -73.93043
# 48375      Eric            Brooklyn    Crown Heights  40.66986  -73.93772
# ...

# %%
data.head(2)
# Out:
#      id                                 name  host_id    host_name  \
# 0  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 1  3831      Cozy Entire Floor of Brownstone     4869  LisaRoxanne
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan        Harlem  40.80902  -73.94190     Private room
# 1            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    150               3                  0         NaN                NaN
# 1     89               1                279  2019-08-29               4.62
#
#    calculated_host_listings_count  availability_365
# 0                               1               365
# 1                               1               192

# %%
data.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48372  False  False    False      False                False          False
# 48373  False  False    False      False                False          False
# 48374  False  False    False      False                False          False
# 48375  False  False    False      False                False          False
# 48376  False  False    False      False                False          False
#
# ...

# %%
import math
def mid(string):
    enum = list(enumerate(string))
    lastnum = enum[-1][0] + 1
    if lastnum % 2 == 0:
        return ""
    else:
        middle = math.floor(len(enum)/2)
        x = enum[middle][1]
        print(x)
        return x

mid("asaba")
# Out:
# a
# 'a'

# %%
x = 'Mining', 'baker', 'Love'
print(x)
# Out:
# ('Mining', 'baker', 'Love')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
listings = pd.read_csv('listings.csv')

# %%
listings
# Out:
#              id                                              name    host_id  \
# 0          3647               THE VILLAGE OF HARLEM....NEW YORK !       4632
# 1          3831                   Cozy Entire Floor of Brownstone       4869
# 2          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 3          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# 4          5121                                   BlissArtsSpace!       7356
# ...         ...                                               ...        ...
# 48372  38564068                                 Top Floor Delight  207204450
# 48373  38564524                             Central Park Elegance    1567562
# 48374  38566777                              Quiet room available  159902221
# 48375  38567542              Spacious room in Brooklyn brownstone   68905617
# 48376  38568081         Petrose home by JFK, Beach &St John Hosp.  293596932
#
# ...

# %%
listings.isnull()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 48372  False  False    False      False                False          False
# 48373  False  False    False      False                False          False
# 48374  False  False    False      False                False          False
# 48375  False  False    False      False                False          False
# 48376  False  False    False      False                False          False
#
# ...

# %%
listings.head(3)
# Out:
#      id                                              name  host_id  \
# 0  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 1  3831                   Cozy Entire Floor of Brownstone     4869
# 2  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 1  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 2        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    150               3                  0         NaN
# 1  Entire home/apt     89               1                279  2019-08-29
# 2  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...
